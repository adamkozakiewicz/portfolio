# %% [markdown]
# # Characters and words calculator

# %% [markdown]
# ## Text analysis:
# ### 1. Characters and words in input text calculator

# %%
import re

# Count characters function
def count_characters(text):
    char_counts = {}
    for char in text:
        char = char.lower()
        if char in char_counts:
            char_counts[char] += 1
        else:
            char_counts[char] = 1

    return char_counts


# Count words function
def count_words(text):

    # Remove special characters from the text
    only_words = re.sub(r'[^A-Za-z0-9\s]', '', text)
    words = only_words.split()

    word_counts = {}
    for word in words:
        word = word.lower()
        if word in word_counts:
            word_counts[word] += 1
        else:
            word_counts[word] = 1

    return word_counts


# Get input text
input_text = input('Enter your text: ')

# Variables for char counts and word counts
char_counts = count_characters(input_text)
word_counts = count_words(input_text)

# Print character and word counts
print('Character counts:')
for char, count in sorted(char_counts.items()):
    print(f"'{char}': {count}")

print('\nWord counts:')
for word, count in sorted(word_counts.items()):
    print(f"'{word}': {count}")
# Out:
# Enter your text:  ed Zeppelin został założony z inicjatywy Jimmy’ego Page’a, muzyka sesyjnego, który miał na swoim koncie współpracę m.in. z Them czy The Kinks[11]. W 1966 dołączył on do bluesowo-rockowej grupy The Yardbirds w miejsce basisty Paula Samwella-Smitha. W niedługim czasie porzucił gitarę basową na rzecz elektrycznej i tym sposobem utworzył podwójny line-up z Jeffem Beckiem. W październiku 1966 Beck odszedł, a sam zespół, zmęczony nieustannym nagrywaniem i koncertowaniem, chylił się ku upadkowi[12]. W tym okresie Page chciał sformować supergrupę – w składzie poza sobą widział także Becka oraz sekcję rytmiczną The Who – Keitha Moona oraz Johna Entwistle[13]. Brał także pod uwagę wokalistów takich jak Steve Winwood oraz Steve Marriott. Grupa w takim kształcie nigdy nie powstała, aczkolwiek Page, Beck, Moon wraz Johnem Paulem Jonesem nagrali utwór „Beck’s Bolero﻿[w innych językach]”, który w 1968 trafił na album Jeff Beck Group zatytułowany Truth[14][15].  The Yardbirds tymczasem przestał istnieć, a ostatni występ miał miejsce w lipcu 1968 w Luton College of Technology w Bedfordshire[16]. Zespół miał zobowiązania koncertowe na terenie Skandynawii, wobec czego perkusista Jim McCarty i wokalista Keith Relf upoważnili Page’a oraz pozostałego w składzie Chrisa Dreję do posługiwania się nazwą „The Yardbirds” aby owe zobowiązania wypełnić. Page i Dreja rozpoczęli formowanie nowego składu. Pierwszym kandydatem Page’a w roli wokalisty był Terry Reid, który odmówił i polecił pochodzącego ze Stourbridge Roberta Planta, który śpiewał w formacjach Band of Joy oraz Hobbstweedle[12]. Plant przyjął propozycję, a sam zarekomendował byłego perkusistę Band of Joy – Johna Bonhama, znanego jako „Bonzo”[1][17]. W tym czasie Dreja zmienił życiowe plany i postanowił zostać fotografem (został potem autorem zdjęcia, zamieszczonego na odwrocie debiutanckiego albumu Led Zeppelin[18]), a tymczasem John Paul Jones za namową swojej żony skontaktował się z Page’em w sprawie wakatu basisty. Jako że gitarzysta znał Jonesa już z poprzednich sesji, zgodził się na jego kandydaturę[12][19]. Tym sposobem skład został skompletowany.  Nie mieliśmy wielkich ambicji. Założyliśmy sobie: Spróbujemy zrobić coś razem i przekonamy się, co z tego wyjdzie[10].  Jimmy Page  Peter Grant: „Dni, w których promotor rzucał kilka funciaków dla zespołów, a sam zgarniał kasę na bramce się skończyły. Menedżerowie, agenci i promotorzy prowadzą biznes, ale zabawne, że to zespoły przyciągają ludzi. I to muzycy powinni zarabiać”[10]. Menedżerem zespołu został Peter Grant, który piastował tę funkcję przez cały czas istnienia Led Zeppelin. To głównie dzięki jego talentowi menedżerskiemu i sile perswazji wobec promotorów zespół osiągał tak dobre wyniki finansowe. W tym miejscu można dodać, że nie było w ogóle żadnej formalnej umowy między Grantem a Led Zeppelin, de facto był on traktowany jako piąty członek zespołu przez cały okres jego funkcjonowania[10]. 12 sierpnia 1968 czwórka muzyków po raz pierwszy zagrała ze sobą w niewielkim pomieszczeniu, znajdującym się pod sklepem muzycznym przy Gerrard Street w Londynie[20][21]. Page zaproponował, aby zagrać „Train Kept A-Rollin﻿[w innych językach]’”, bluesa spopularyzowanego przez Johnny’ego Burnette’a, którego cover swego czasu przygotował The Yardbirds. Jones: „Gdy tylko usłyszałem grę Johna Bonhama, wiedziałem że wszystko wypali… Od razu staliśmy się zespołem”[22].  Przed wyjazdem na półwysep skandynawski, grupa wzięła udział w nagraniu albumu Three Week Hero P.J. Proby[23]. Pochodzący z tego wydawnictwa „Jim’s Blues”, gdzie Plant zagrał na harmonijce, był pierwszym utworem studyjnym nagranym razem przez przyszłych członków Led Zeppelin[22]. Formacja pod nazwą The New Yardbirds[24] wyruszyła w trasę po Skandynawii, dając pierwszy występ 7 września 1968 w Gladsaxe Teen Clubs w duńskim Gladsaxe[25][22]. W październiku[1] lub w listopadzie[26] zespół przystąpił do nagrywania debiutanckiego albumu na podstawie zestawu utworów, które wykon ...
# Character counts:
# ' ': 1236
# '(': 5
# ')': 5
# ',': 86
# '-': 4
# '.': 68
# '0': 18
# '1': 49
# '2': 32
# '3': 15
# '4': 4
# '5': 7
# '6': 16
# '7': 6
# '8': 10
# '9': 14
# ':': 8
# '[': 54
# ']': 54
# 'a': 632
# 'b': 130
# 'c': 207
# 'd': 212
# 'e': 575
# 'f': 34
# 'g': 126
# 'h': 83
# 'i': 493
# 'j': 136
# 'k': 191
# 'l': 181
# 'm': 215
# 'n': 386
# 'o': 503
# 'p': 253
# 'q': 1
# 'r': 333
# 's': 325
# 't': 310
# 'u': 176
# 'v': 8
# 'w': 315
# 'x': 3
# 'y': 292
# 'z': 345
# 'é': 2
# 'ó': 59
# 'ą': 54
# 'ć': 20
# 'ę': 74
# 'ł': 166
# 'ń': 4
# 'ś': 32
# 'ź': 7
# 'ż': 38
# '–': 8
# '’': 12
# '”': 19
# '„': 19
# '…': 1
# '﻿': 3
#
# Word counts:
# '000': 2
# '12': 2
# '15': 1
# '150': 1
# '1782': 1
# '1966': 2
# '1968': 6
# '196832': 1
# '1969': 1
# '200': 1
# '25': 2
# '26': 1
# '31': 1
# '7': 1
# 'a': 11
# 'aby': 3
# 'aczkolwiek': 1
# 'adnej': 1
# 'agenci': 1
# 'album': 5
# 'albumu': 6
# 'albumw': 2
# 'ale': 1
# 'ambicji': 1
# 'ameryce': 1
# 'amerykaskiej': 1
# 'and': 1
# 'anglii': 3
# 'ani': 1
# 'arollinw': 1
# 'artystycznie': 1
# 'atlantic': 2
# 'autorem': 1
# 'autorstwo': 1
# 'babyw': 1
# 'bad': 1
# 'balon': 1
# 'baloon': 1
# 'baloon29': 1
# 'band': 2
# 'bardzo': 2
# 'basisty': 2
# 'basow': 1
# 'bdc': 1
# 'beck': 4
# 'becka': 1
# 'beckiem': 1
# 'becks': 1
# 'bedfordshire16': 1
# 'billboard36': 1
# 'biznes': 1
# 'blues': 1
# 'bluesa': 2
# 'bluesoworockowej': 1
# 'bolerow': 1
# 'bonhama': 2
# 'bonzo117': 1
# 'botem': 1
# 'bowiem': 1
# 'boys': 1
# 'bra': 1
# 'bramce': 1
# 'breakdown': 1
# 'brytyjsk': 1
# 'brytyjska': 1
# 'brytyjskie': 1
# 'brytyjskim': 1
# 'burnettea': 1
# 'butterfly': 1
# 'by': 6
# 'bya': 4
# 'byego': 1
# 'bylimy': 1
# 'byo': 2
# 'cant': 1
# 'cay': 2
# 'charakter': 1
# 'chcia': 2
# 'chicagowskiej': 1
# 'chodzi': 1
# 'chrisa': 1
# 'chyli': 1
# 'ciar': 1
# 'cieszy': 1
# 'clubs': 1
# 'co': 4
# 'cole': 2
# 'college': 1
# 'communication': 1
# 'confused': 1
# 'cover': 1
# 'cushions10': 1
# 'cz': 1
# 'czas': 1
# 'czasem': 1
# 'czasie': 4
# 'czasu': 1
# 'czego': 1
# 'czonek': 1
# 'czonkw': 1
# 'czonu': 1
# 'czwrka': 1
# 'czy': 4
# 'czym': 1
# 'd': 1
# 'daa': 1
# 'dajc': 1
# 'dazed': 1
# 'de': 1
# 'debiutanckiego': 3
# 'decyzji': 1
# 'denver': 1
# 'dixona': 1
# 'dla': 4
# 'dlatego': 2
# 'dni': 1
# 'do': 5
# 'dobr': 1
# 'dobre': 1
# 'dobrego': 1
# 'dobry': 1
# 'dobrze': 1
# 'doczy': 1
# 'doda': 1
# 'dogs': 1
# 'dokadnie': 1
# 'dolarw': 2
# 'doskonaych': 1
# 'drej': 2
# 'dreja': 2
# 'duskim': 1
# 'dusty': 1
# 'dwa': 1
# 'dzieo': 1
# 'dziesitej': 1
# 'dziewiciodniowej': 1
# 'dziki': 1
# 'e': 8
# 'ed': 1
# 'elektrycznej': 1
# 'emi': 1
# 'entwistle13': 1
# 'entwistlowi': 1
# 'erlewine': 1
# 'estetyki': 1
# 'facto': 1
# 'faktu': 1
# 'finansowe': 1
# 'fly': 1
# 'formacja': 1
# 'formacjach': 1
# 'formalnej': 1
# 'formowanie': 1
# 'fotografem': 1
# 'fudge': 1
# 'funciakw': 1
# 'funkcj': 1
# 'funkcjonowania10': 1
# 'funtw10': 1
# 'funty27': 1
# 'gaa': 1
# 'gdy': 2
# 'gdzie': 1
# 'gerrard': 1
# 'gitar': 1
# 'gitarzysta': 2
# 'gladsaxe': 1
# 'gladsaxe2522': 1
# 'good': 1
# 'gr': 1
# 'grajcego': 1
# 'grant': 4
# 'grantem': 1
# 'grantowi': 1
# 'group': 1
# 'grudnia': 1
# 'grup': 1
# 'grupa': 3
# 'grupie': 1
# 'grupie3013': 1
# 'grupy': 1
# 'guildford': 1
# 'gwarantowaa': 1
# 'gwiazdy10': 1
# 'gwn': 1
# 'gwnej': 1
# 'gwnie': 1
# 'hard': 1
# 'hardrockowych': 1
# 'harmonijce': 1
# 'hasem': 1
# 'heavy': 1
# 'heavymetalowych11': 1
# 'hero': 1
# 'hindenburga': 1
# 'hobbstweedle12': 1
# 'how': 1
# 'i': 27
# 'inicjatywy': 1
# 'inni': 1
# 'innych': 3
# 'iron': 1
# 'istnie': 1
# 'istnienia': 1
# 'jak': 3
# 'jakiego': 1
# 'jakiej': 1
# 'jako': 6
# 'jednoczenie': 1
# 'jednym': 1
# 'jedyne': 1
# 'jeff': 1
# 'jeffem': 1
# 'jego': 3
# 'jej': 1
# 'jeli': 1
# 'jestemy': 1
# 'jim': 1
# 'jimmy': 1
# 'jimmyego': 1
# 'jims': 1
# 'john': 2
# 'johna': 3
# 'johnem': 1
# 'johnnyego': 1
# 'jones': 3
# 'jonesa': 1
# 'jonesem': 1
# 'joy': 2
# 'ju': 2
# 'jzykach': 3
# 'kandydatem': 1
# 'kandydatur1219': 1
# 'kas': 1
# 'katastrofy': 1
# 'keith': 1
# 'keitha': 1
# 'kept': 1
# 'kilka': 2
# 'kinks11': 1
# 'klaska': 1
# 'klaszcz': 1
# 'kogo': 1
# 'kolejn': 1
# 'kolejnych': 1
# 'koncert': 1
# 'koncertem': 1
# 'koncertowaniem': 1
# 'koncertowe': 1
# 'koncertowych': 1
# 'koncertw': 1
# 'koncie': 1
# 'koniec': 1
# 'kontrakt': 1
# 'kontraktu': 1
# 'kopot': 1
# 'koszty': 1
# 'krtkie': 1
# 'ksztacie': 1
# 'ktre': 1
# 'ktrego': 1
# 'ktrej': 1
# 'ktry': 5
# 'ktrych': 1
# 'ku': 1
# 'kwestia': 1
# 'kwestii': 2
# 'latach': 1
# 'lead': 1
# 'led': 12
# 'leed14': 1
# 'lekko2917': 1
# 'lineup': 1
# 'lipcu': 2
# 'listopadzie26': 1
# 'liter': 1
# 'londynie2021': 1
# 'lub': 1
# 'lubi': 1
# 'ludzi': 1
# 'ludzie': 1
# 'luton': 1
# 'mad': 2
# 'many': 1
# 'marca33': 1
# 'marriott': 1
# 'mas': 1
# 'mccarty': 1
# 'me': 1
# 'menaderem': 1
# 'menederem': 1
# 'menederowie': 1
# 'menederskiemu': 1
# 'metalu34': 1
# 'mg': 1
# 'mia': 4
# 'miaa': 1
# 'miay': 1
# 'midzy': 1
# 'miejsce': 3
# 'miejscu': 1
# 'mielimy': 2
# 'miesicy': 1
# 'min': 2
# 'mocno': 1
# 'moglimy': 1
# 'mona': 1
# 'moon': 1
# 'moona': 1
# 'moonowi': 1
# 'more': 1
# 'mu': 1
# 'muzycy': 1
# 'muzyczna': 1
# 'muzycznej': 1
# 'muzycznym': 1
# 'muzyka': 1
# 'muzykw': 2
# 'na': 23
# 'nagrali': 1
# 'nagralimy': 1
# 'nagraniu': 1
# 'nagranym': 1
# 'nagrywania': 2
# 'nagrywaniem': 1
# 'naiwnoci': 1
# 'najpierw': 2
# 'najwysza': 1
# 'nam': 1
# 'namow': 1
# 'napisa': 1
# 'narzeka': 1
# 'nas': 2
# 'nastpia': 1
# 'nastpnie': 2
# 'naszego': 1
# 'naszej': 1
# 'natchnienia': 1
# 'natomiast': 2
# 'nawet': 1
# 'nazw': 3
# 'nazwy': 2
# 'new': 2
# 'nie': 13
# 'niedugim': 1
# 'niepotrzebny': 1
# 'nieprzychylne': 1
# 'niespodziewany': 1
# 'nieustannym': 1
# 'niewielkim': 1
# 'niewtpliwie': 1
# 'niewyczerpanym': 1
# 'nigdy': 1
# 'nikt': 2
# 'nimi': 1
# 'niskie': 1
# 'notowania': 1
# 'nowego': 1
# 'nowej': 1
# 'nowo': 1
# 'o': 1
# 'obejmujc': 1
# 'obrzucono': 1
# 'od': 1
# 'odbya': 1
# 'odgrywa': 1
# 'odmianie': 1
# 'odmwi': 1
# 'odmwia': 1
# 'odszed': 1
# 'odwrocie': 1
# 'of': 4
# 'ogle': 1
# 'okadce': 1
# 'okaza': 1
# 'okazaa': 1
# 'okoo': 1
# 'okres': 1
# 'okresie': 1
# 'on': 2
# 'oni': 1
# 'only': 1
# 'ony': 1
# 'oowiany': 1
# 'opieraj': 1
# 'opini': 1
# 'oraz': 9
# 'organizacji': 1
# 'osiga': 1
# 'ostatni': 1
# 'ostroni': 1
# 'otrzyma': 1
# 'owce10': 1
# 'owe': 1
# 'owym': 1
# 'padziernika': 1
# 'padziernika28': 1
# 'padzierniku': 2
# 'padzierniku1': 1
# 'page': 7
# 'page22': 1
# 'pagea': 4
# 'pageem': 1
# 'paul': 2
# 'paula': 1
# 'paulem': 1
# 'pen': 2
# 'perkusist': 1
# 'perkusista': 1
# 'perswazji': 1
# 'peter': 4
# 'piastowa': 1
# 'pierwszego': 2
# 'pierwszy': 4
# 'pierwszych': 1
# 'pierwszym': 2
# 'piewa': 1
# 'pikowaaby': 1
# 'pisze': 1
# 'pity': 1
# 'pj': 1
# 'plant': 3
# 'planta': 1
# 'plany': 1
# 'plus': 1
# 'pniej': 1
# 'pnocnej': 1
# 'po': 6
# 'pochodzcego': 1
# 'pochodzcy': 1
# 'pocztkowo': 1
# 'pod': 4
# 'podpisa': 1
# 'podstawie': 2
# 'podsumowa': 1
# 'podwjny': 1
# 'pojawi': 1
# 'pojechalimy': 1
# 'pokadzie': 1
# 'pokry': 1
# 'poleci': 1
# 'pomieszczeniu': 1
# 'poprzednich': 1
# 'porzuci': 1
# 'postaci': 1
# 'postanowi': 1
# 'posugiwania': 1
# 'potem': 3
# 'potrzeby': 1
# 'powinni': 1
# 'powodu': 1
# 'powstaa': 1
# 'powstaej': 1
# 'poza': 1
# 'pozostaego': 1
# 'pozwany': 1
# 'pozycj': 1
# 'pozycji': 1
# 'pras': 1
# 'prasa': 1
# 'prasie21': 1
# 'premiera': 1
# 'proby23': 1
# 'promotor': 2
# 'promotorw': 1
# 'promotorzy': 1
# 'promowany': 1
# 'propozycj': 1
# 'prowadz': 1
# 'przeczytalimy': 1
# 'przed': 1
# 'przedstawiona': 1
# 'przejaww': 1
# 'przekonamy': 1
# 'przesta': 1
# 'przez': 6
# 'przy': 1
# 'przycigaj': 1
# 'przygotowa': 1
# 'przyj': 1
# 'przyjtej': 1
# 'przypisuje': 1
# 'przystpi': 1
# 'przyszoci': 1
# 'przyszych': 1
# 'przyznana': 1
# 'publicznoci': 1
# 'punktem': 1
# 'pwysep': 1
# 'pyta': 1
# 'pyty': 1
# 'quit': 1
# 'raz': 1
# 'razem': 2
# 'razu': 1
# 'rdem': 1
# 'recenzj': 1
# 'recenzje': 1
# 'records': 1
# 'reid': 1
# 'rekomendacji': 1
# 'relf': 1
# 'reputacj': 1
# 'richard': 1
# 'roberta': 1
# 'robi': 1
# 'rocka': 2
# 'rodakw': 1
# 'rodzimej': 1
# 'rodzinnej': 1
# 'roku': 1
# 'rol': 1
# 'roli': 1
# 'rolling': 1
# 'rozgldaj': 1
# 'rozpatrywano': 1
# 'rozpoczli': 1
# 'rozwoju': 1
# 'rynku': 1
# 'rytmiczn': 1
# 'rzecz': 1
# 'rzeczywicie': 1
# 'rzuca': 1
# 's': 1
# 'sabe': 1
# 'sam': 3
# 'samego': 1
# 'sami': 1
# 'samwellasmitha': 1
# 'sdzilimy': 1
# 'sekcj': 1
# 'sesji': 2
# 'sesyjnego': 1
# 'sformowa': 1
# 'shook': 1
# 'si': 24
# 'sierpnia': 1
# 'sile': 1
# 'single': 2
# 'skad': 1
# 'skadu': 1
# 'skadzie': 2
# 'skandynawii': 2
# 'skandynawski': 1
# 'sklepem': 1
# 'skoczyy': 1
# 'skompletowany': 1
# 'skontaktowa': 1
# 'sob': 2
# 'sobie': 1
# 'sowo': 1
# 'spopularyzowanego': 1
# 'sposobem': 2
# 'sprawach': 1
# 'sprawie': 1
# 'sprawnym': 1
# 'sprawy': 1
# 'sprbujemy': 1
# 'springfield31': 1
# 'sta': 1
# 'stalimy': 1
# 'standardy': 1
# 'stanw': 1
# 'staralimy': 1
# 'status': 1
# 'stawki': 1
# 'stephen': 1
# 'sterowca': 1
# 'steve': 2
# 'stone': 1
# 'stourbridge': 1
# 'street': 1
# 'studyjnym': 1
# 'stwierdz': 1
# 'stwierdzili': 1
# 'stycznia': 1
# 'suma': 1
# 'supergrup': 1
# 'supergrupa': 1
# 'supportu': 1
# 'surrey': 1
# 'swego': 1
# 'swj': 1
# 'swobod': 2
# 'swoich': 1
# 'swoim': 1
# 'swojej': 1
# 'symbolizujcym': 1
# 'szst13': 1
# 'szum': 1
# 'szy': 1
# 'szyldu': 1
# 't': 1
# 'ta': 1
# 'tak': 4
# 'take': 4
# 'taki': 1
# 'takich': 1
# 'takim': 1
# 'talentowi': 1
# 'tam': 1
# 'technology': 1
# 'teen': 1
# 'tego': 3
# 'ten': 1
# 'terenie': 1
# 'terminw': 1
# 'terry': 1
# 'the': 13
# 'them': 1
# 'three': 1
# 'times': 2
# 'times11': 1
# 'to': 7
# 'tourne': 2
# 'trafi': 1
# 'train': 1
# 'traktowany': 1
# 'tras': 4
# 'trasy22': 1
# 'truth1415': 1
# 'twrczo': 1
# 'tylko': 5
# 'tym': 7
# 'tymczasem': 2
# 'tytuem': 1
# 'udao': 3
# 'udzia': 1
# 'udzielia': 1
# 'ukaza': 1
# 'ukuto': 1
# 'umowa': 1
# 'umowy': 1
# 'unika': 1
# 'university': 1
# 'upadkowi12': 1
# 'uplasowa': 1
# 'upowanili': 1
# 'usa': 1
# 'usyszaem': 1
# 'usyszawszy': 1
# 'utrzymywa': 1
# 'utworem': 1
# 'utworw': 2
# 'utwory': 1
# 'utworzy': 1
# 'utwr': 1
# 'uwag': 1
# 'uwierzy': 1
# 'uywa': 1
# 'uzyska': 1
# 'vanilla': 1
# 'w': 51
# 'wakatu': 1
# 'wanie': 1
# 'way': 1
# 'week': 1
# 'weiss': 1
# 'weryfikowana': 1
# 'who': 2
# 'whoopie': 1
# 'widzia': 1
# 'wiedziaem': 1
# 'wielkich': 1
# 'wielokrotnie': 1
# 'wielu': 1
# 'wiesaw': 1
# 'williego': 1
# 'winwood': 1
# 'wobec': 2
# 'wok': 1
# 'wokalista': 1
# 'wokalistw': 1
# 'wokalisty': 1
# 'wraz': 1
# 'wrzenia': 1
# 'wschodnie': 1
# 'wspprac': 1
# 'wszystko': 1
# 'wtedy': 1
# 'wwczas': 2
# 'wybierania': 1
# 'wybrzee': 1
# 'wychodzia': 1
# 'wydane': 1
# 'wydawnictwa': 1
# 'wyjazdem': 1
# 'wyjdzie10': 1
# 'wykonywa': 1
# 'wykorzystane': 1
# 'wymawia': 1
# 'wynegocjowa': 1
# 'wyniki': 1
# 'wynoszce': 1
# 'wypali': 1
# 'wypeni': 1
# 'wyraeniem': 1
# 'wyruszya': 1
# 'wyrzuci': 1
# 'wysokoci': 1
# 'wystp': 3
# 'wystp37': 1
# 'wystpie': 1
# 'wystpowa': 1
# 'wytwrnia': 1
# 'wzajemnoci': 1
# 'wzia': 1
# 'wzrosa': 1
# 'yardbirds': 5
# 'yardbirds24': 1
# 'yciowe': 1
# 'you': 2
# 'ywo': 1
# 'ywo35': 1
# 'z': 13
# 'za': 3
# 'zabawne': 1
# 'zachodnie': 1
# 'zaczn': 1
# 'zagra': 2
# 'zagraa': 1
# 'zagralimy': 1
# 'zainteresowana': 1
# 'zakoczonej': 1
# 'zakorzeniona': 1
# 'zaliczki': 1
# 'zamieszczonego': 1
# 'zanim': 2
# 'zaoony': 1
# 'zaoylimy': 1
# 'zaproponowa': 2
# 'zarabia10': 1
# 'zarekomendowa': 1
# 'zastpione': 1
# 'zatytuowany': 1
# 'zawartoci': 1
# 'zdjcia': 1
# 'zdjcie': 1
# 'zdoby': 2
# 'zdobylimy': 1
# 'ze': 3
# 'zeppelin': 11
# 'zeppelin13': 1
# 'zeppelin18': 1
# 'zeppelin22': 1
# 'zesp': 6
# 'zespoem22': 1
# 'zespou': 6
# 'zespow': 1
# 'zespoy': 1
# 'zestawie': 1
# 'zestawu': 1
# 'zgarnia': 1
# 'zgodzi': 1
# 'ziemi': 1
# 'zmczony': 1
# 'zmieni': 1
# 'zmienia': 1
# 'zna': 2
# 'znajdujcym': 1
# 'znalazy': 1
# 'znanego': 1
# 'zobaczywszy': 1
# 'zobowizania': 2
# 'zorganizowa': 1
# 'zosta': 6
# 'zostao': 1
# 'zotej': 1
# 'zrealizowaniu': 1
# 'zreszt': 1
# 'zrobi': 1
# 'zwaszcza': 2
# 'zwrotnym': 1

# %% [markdown]
# ### 2. Example: output for "Psychodelic rock" wiki page in polish: (only character counts)
#
# "Rock psychodeliczny silnie związany był zwłaszcza z ruchem hippisowskim, stanowiąc główny środek artystycznego wyrazu ideologii „Dzieci kwiatów”. Nazwa pochodzi zatem od tzw. psychodelików, substancji psychoaktywnych, które zbuntowana młodzież lat 60. zażywała w celu osiągnięcia odmiennych stanów świadomości. Rock psychodeliczny przyczynił się jednocześnie do powstania takich gatunków muzyki rockowej jak hard rock, rock progresywny czy nawet heavy metal. Za prekursora rocka psychodelicznego uważa się amerykański zespół The Charlatans, utworzony w 1964 w San Francisco. Działalność zespołu była bezpośrednią inspiracją dla utworzenia grupy Grateful Dead (wcześniej The Warlocks). Określenia „muzyka psychedeliczna” po raz pierwszy użyła grupa 13th Floor Elevators w wywiadzie udzielonym w 1966 i na swojej pierwszej płycie The Psychedelic Sounds of the 13th Floor Elevators (1966).
#
# Pierwotnie rock psychodeliczny wywodził się z tradycyjnego rockandrolla oraz bluesa, odchodząc w stronę muzycznej awangardy, wzorców dalekowschodnich (np. ragi) a nawet muzyki elektronicznej i jazzu. Bardziej konwencjonalną odmianę psychodelicznego rocka stanowi acid rock.
#
# Samo określenie „psychodeliczny” oznacza „odkrywający umysł” odmienny stan świadomości, charakteryzujący się zwiększoną wrażliwością umysłu na wewnętrzne doznania i zewnętrzne bodźce. W istocie, w przypadku słuchaczy i zwykle twórców tej muzyki, stan ten wywołany był zażywaniem substancji psychoaktywnych jak np. marihuana, meskalina, LSD-25. Muzyka zaś starała się odzwierciedlić muzycznie stan człowieka pod wpływem psychodelików, głównie LSD.
#
# Psychodeliczny rock charakteryzował się odejściem od tradycyjnej czterotaktowej struktury rockandrolla na rzecz swobodnych form muzycznych oraz od standardu trzyipółminutowej piosenki na rzecz dłuższych form, które na koncertach mogły się przekształcić w niekończące się jamy. Cechował się także wpływami jazzu i muzyki innych kultur, głównie indyjskiej (przejawiającymi się wprowadzeniem egzotycznych instrumentów, jak sitar) oraz poetyckimi tekstami, często mistycznymi lub surrealistycznymi, kojarzącymi się z wizjami.
#
# Rock psychodeliczny wywarł wpływ na większość gatunków rocka dominujących w kolejnych dziesięcioleciach, zwłaszcza stał się prekursorem acid rocka i rocka progresywnego. W latach 90. XX wieku do nurtu rocka psychodelicznego nawiązała m.in. grupa Kula Shaker."

# %%
"""
char_counts = {
' ': 305,
'(': 4,
')': 4,
',': 19,
'-': 1,
'.': 22,
'0': 2,
'1': 5,
'2': 1,
'3': 2,
'4': 1,
'5': 1,
'6': 6,
'9': 4,
'a': 163,
'b': 12,
'c': 127,
'd': 69,
'e': 135,
'f': 7,
'g': 23,
'h': 50,
'i': 143,
'j': 36,
'k': 73,
'l': 51,
'm': 48,
'n': 116,
'o': 138,
'p': 50,
'r': 105,
's': 95,
't': 77,
'u': 55,
'v': 3,
'w': 96,
'x': 2,
'y': 103,
'z': 111,
'ó': 17,
'ą': 16,
'ć': 4,
'ę': 21,
'ł': 35,
'ń': 2,
'ś': 15,
'ź': 1,
'ż': 8,
'”': 4,
'„': 4,
}
"""
# Out:
# "\nchar_counts = {\n' ': 305,\n'(': 4,\n')': 4,\n',': 19,\n'-': 1,\n'.': 22,\n'0': 2,\n'1': 5,\n'2': 1,\n'3': 2,\n'4': 1,\n'5': 1,\n'6': 6,\n'9': 4,\n'a': 163,\n'b': 12,\n'c': 127,\n'd': 69,\n'e': 135,\n'f': 7,\n'g': 23,\n'h': 50,\n'i': 143,\n'j': 36,\n'k': 73,\n'l': 51,\n'm': 48,\n'n': 116,\n'o': 138,\n'p': 50,\n'r': 105,\n's': 95,\n't': 77,\n'u': 55,\n'v': 3,\n'w': 96,\n'x': 2,\n'y': 103,\n'z': 111,\n'ó': 17,\n'ą': 16,\n'ć': 4,\n'ę': 21,\n'ł': 35,\n'ń': 2,\n'ś': 15,\n'ź': 1,\n'ż': 8,\n'”': 4,\n'„': 4,\n}\n"

# %% [markdown]
# ### 3. Polish version of "Scrabble" - letters appearance

# %%
scrabble = {
'a': 9,
'b': 2,
'c': 3,
'd': 3,
'e': 7,
'f': 1,
'g': 2,
'h': 2,
'i': 8,
'j': 2,
'k': 3,
'l': 3,
'm': 3,
'n': 5,
'o': 6,
'p': 3,
'r': 4,
's': 4,
't': 3,
'u': 2,
'v': 0,
'w': 4,
'x': 0,
'y': 4,
'z': 5,
'ó': 1,
'ą': 1,
'ć': 1,
'ę': 1,
'ł': 1,
'ń': 1,
'ś': 1,
'ź': 1,
'ż': 1
}

# %% [markdown]
# ### 4. Dictionaries preparation

# %%
# Convert to percentages function
def convert_to_percentages(dictionary):
    summary = sum(dictionary.values())
    # Avoid division by zero
    if summary == 0:
        return {key: 0 for key in dictionary}
    return {key: (value / summary) * 100 for key, value in dictionary.items()}

# Convert to percentages
scrabble = convert_to_percentages(scrabble)
char_counts = convert_to_percentages(char_counts)


# Filter function 
def filter(dict1, dict2):
    return {key: dict1[key] for key in dict1 if key in dict2}

# Filter char_counts to include only keys that exist in scrabble
char_counts = filter(char_counts, scrabble)

# %% [markdown]
# ### 5. Letters appearance comparison (Wiki page vs Scrabble)

# %%
import matplotlib.pyplot as plt

# Create lists for comparison
union_keys = set(char_counts.keys()).union(scrabble.keys())
char_values = [char_counts.get(key) for key in union_keys]
scrabble_values = [scrabble.get(key) for key in union_keys]

# Create bar chart
plt.bar(x, char_values, width=0.4, label='Character appearance', align='center')
plt.bar(x, scrabble_values, width=0.4, label='Scrabble appearance', align='edge')
plt.ylabel('Counts percent')
plt.title('Comparison of Character appearance vs Scrabble appearance')
x = range(len(union_keys))
plt.xticks(x, union_keys)
plt.legend()
plt.tight_layout()
